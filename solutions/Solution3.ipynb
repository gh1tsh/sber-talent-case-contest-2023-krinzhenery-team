# %% [markdown]
# # Решение 3 (равное голосование)

# %% [markdown]
# ## Загрузка данных

# %%
from src import *
data = load_dataset.load()

# %%
data
# Out:
# ['ты нашел их или нет',
#  'почему она так со мной поступает',
#  'никто туда больше не ходит',
#  'у него с собой не было тогда денег',
#  'почему они с нами так поступают',
#  'он всю ночь стонал от сильной боли',
#  'я больше не хочу с тобой играть',
#  'тому было тогда всего тринадцать лет',
#  'что сделал том с деньгами',
#  'том меня сейчас хочет видеть',
#  'он даже меня не замечает',
#  'тебе это все нравится',
#  'у него тогда не было с собой денег',
#  'я его больше не увижу',
#  'почему она так с ней поступает',
#  'я хотел бы учиться в бостоне',
#  'том и мэри объявили сегодня о своей пбмолвке',
#  'том этим сейчас занимается',
#  'я не могу больше ждать',
#  'мост очень длинный и высокий',
#  'том был просто не готов',
#  'пусть свиньи это едят',
#  'я ничего не хочу делать',
#  'ты хотел мне рассказать о свободе',
#  'что пел джон на сцене',
#  'я написал влера письмо',
#  'тому это тоже не нравится',
#  'сколько сейчас времени в париже',
#  'мы не были готовы',
#  'они их только что нашли',
#  'тому было больше не к кому обратиться',
#  'том не знает ничего о семье мэри',
#  'я живу сейчас в бостоне',
#  'я ничего не хочу пить',
#  'мне нужны будут подробности',
#  'мы ничего не можем сделать',
#  'он сказал что вчера был дома',
#  'твои комментарии мне всегда очень помогали',
#  'они никогда меня не слушают',
#  'они три года провели в тюрьме',
#  'вчера был просто не мой день',
#  'я поймал сегодня три рыбы',
#  'я хочу что-нибудь сделать для тома',
#  'тому было нечего сказать',
#  'я сделал все правильно',
#  'я напишу или позвоню тебе на следующей неделе',
#  'я тоже завтра пойду в университет',
#  'чем ты будешь заниматься завтра в это время',
#  'я хотел бы быть камнем',
#  'я рмогу там быть через час',
#  'мне никогда не нужно было столько денег',
#  'том бы никогда не согласился',
#  'извините я хотел бы ьто примерить',
#  'кто мне может это объяснить',
#  'ты не будешь один',
#  'том сегодня не может прийти',
#  'я тебя видел с высоким парнем',
#  'я не езжу в школу на автобусе',
#  'она все свои деньги тратит на одежду',
#  'том не может жить без мэри',
#  'том всегда меня смешит',
#  'том мне сегодня это сказал',
#  'я видел тебя с высоким парнем',
#  'я хочу сделать что-то со своей жизнью',
#  'почему все на нас смотрят',
#  'том здесь больше не работает',
#  'я редко видел его в школе',
#  'я думаю вса время о томе',
#  'мы много времени провгдим вместе',
#  'почему они так с ним поступают',
#  'я больше не могу ждать',
#  'что могло с ними случиться',
#  'мы будем делать все по-своему',
#  'я сейчас не могу говорить',
#  'я езжу в школу не на автобусе',
#  'где был том весь день',
#  'я здесь часто ем',
#  'мы их только что нашли',
#  'я все ей рассказываю',
#  'я думаю все время о томе',
#  'том хочет меня сейчас видеть',
#  'том больше мне не доверяет',
#  'никто не знает чуо на самом деле происходит',
#  'какая гора самая высокая в мире',
#  'том не может сейчас подойти к телефону',
#  'что джон пел на сцене',
#  'том не хочет никого видеть',
#  'многие птицы осенью улетают на юг',
#  'какое это имеет отношение к школе',
#  'я не хотел ввести никого в заблуждение',
#  'что сделел том с деньгами',
#  'том нам ничего не дал',
#  'я покажу вам несколько фотографий',
#  'здесь есть поблизости банкомат',
#  'у меня нет дома компьютера',
#  'мы теряем здесь время',
#  'я не могу сейчас говорить',
#  'можешь меня высадить у библиотеки',
#  'том был мне как отец',
#  'я сделал это все для тебя',
#  'я больше его не увижу',
#  'мне было не с кем поговорить',
#  'я хотел бы столик у окна',
#  'тем ничего нам не платит',
#  'с этим нужно что-то немедленно делать',
#  'никто не знает что на самом деле происходит',
#  'том больше здесь не работает',
#  'том уже это сделал',
#  'том никогда мне не казывал свою фамилию',
#  'том бы никогда не соглхсился',
#  'я его редко видел в школе',
#  'том никогда тебя больше не увидит',
#  'я бы тоже хотел услышать твой голос',
#  'я больше не могу доверять тому',
#  'том сегодня будет здесь',
#  'я бы хотел порисовать',
#  'лакая гора самая высокая в европе',
#  'я хочу сделать что-то со своей жизною',
#  'извините я хотел бы это примерить',
#  'мы их никогда не найдем',
#  'том меня всегда смешит',
#  'том тогда был здесь',
#  'мы только что их нашли',
#  'ты играешь в футбол или регби',
#  'я говорю также на испанском',
#  'у меня дома нет компьютера',
#  'зачем тому была нужна отвертка',
#  'я бы хотел поехать во францию',
#  'я ничего не могу найти',
#  'мне нечего было скрывать',
#  'я здесь никого не знаю',
#  'том был тогда здесь',
#  'я тебя не спрашиваю том',
#  'этой мечте было не суждено осуществиться',
#  'том никогда больше тебя не увидит',
#  'я привык что том все время на меня орет',
#  'том тебе звонил вчера вечером',
#  'том ничего нам не платит',
#  'я сегодня не был занят',
#  'ты хотел рассказать мне о свободе',
#  'я тебе уже все сказал',
#  'странно что никто нас не знает',
#  'он не был готов',
#  'я не живу в финляндии',
#  'вчера просто был не мой день',
#  'я ему заплатил на прошлой неделе',
#  'я правда тебя не понимаю',
#  'говорят в горах погода быстро меняется',
#  'мне придется это ещм раз обдумать',
#  'почему он так со мной поступает',
#  'сколько тебе тогда было лет',
#  'прибавить пять к десяти легко',
#  'он не сказал мно ни слова',
#  'думаю я мог бы и один это сделать',
#  'я бы хотел выучить финский',
#  'у тебя есть дома компьютер',
#  'хирург забыл что-то внутри пациента',
#  'он не может больше идти',
#  'том сможет это сделать без нашей помощи',
#  'он никогда мне не помогает',
#  'том яблоко ест или банан',
#  'мы сегодня поговорим с томом',
#  'том мне действует на нервы',
#  'том обещал никогда этого больше не делать',
#  'я просто был невнимателен',
#  'том был не единственным свидетелем',
#  'ты в футбол играешь или в регби',
#  'я заплатил ему на прошлой неделе',
#  'том очень мае помог',
#  'ты едешь на поезде или на машине',
#  'не слышно было ни звука',
#  'почему она с ним так поступает',
#  'том не может сегодня прийти',
#  'мне придется это еще раз обдумать',
#  'я там встретил тома',
#  'мне сегодня не нужно никуда идти',
#  'том не живет в бостоне',
#  'я вчера неплохо провел время',
#  'у меня есть кое-что для тома',
#  'я бы хотел выучить латышсккй',
#  'я не хочу больше на вас работать',
#  'мэри была не готова',
#  'все говорят что они невиновны',
#  'том больше не может здесь оставаться',
#  'том продал сегоднь три холодильника',
#  'у тебя в детстве была любимая книга',
#  'том ничего нам не дал',
#  'я знаю что все вы трусы',
#  'он был тогда в америке',
#  'у тебя дома есть компьютер',
#  'мэри говорит что ничего не будет делать',
#  'я жить не могу без тома',
#  'тому был нужен молоток',
#  'он тогда был в америке',
#  'я никогда ни о чем тебя не просил',
#  'она сказала что вчера была дома',
#  'я только что это сделал',
#  'я полностью с ними согласен',
#  'я вам покажу несколько фотографий',
#  'я тебе напишу или позвоню на следующей неделе',
#  'мы не были так заняты',
#  'ты не будеоь один',
#  'мне пришлось все делать самому',
#  'здесь поблизости есть банкомат',
#  'том не хотел никуда идти',
#  'я не хочу ничего читать',
#  'я никогда не забуду выражение его лица',
#  'что еще я получу',
#  'у меня тоже сегодня контрольная',
#  'они провели три года в тюрьме',
#  'я буду там в пять',
#  'мы больше не хотим ждать',
#  'я никогда от тебя ничего не скрывал',
#  'я ничего не хочу читать',
#  'все они говорят что невиновны',
#  'она никогда нам ничего не рассказывает',
#  'я кричу но никто меня не слышит',
#  'они не были готовы',
#  'я ничего им не дал',
#  'не думаю что можно что-то сделать',
#  'я не был сегодня занят',
#  'том ест яблоко или банан',
#  'я думаю что здесь мы в безопасности',
#  'ты на поезде едешь или на машине',
#  'я был вынужден уйти',
#  'она была не готова',
#  'фильм показался мне интересным',
#  'хорошо что тома здесь нет',
#  'я живу не в финляндии',
#  'почему ты просто не можешь позвонить им',
#  'им были нужны деньги',
#  'том ничего мне не говорит',
#  'я бы хотел поцеловать мэри',
#  'почему она так с ним поступает',
#  'я просто хочу исчезнуть',
#  'я только что его доделал',
#  'я завтра им позвоню',
#  'на печи старая кошка возится со своими котятами',
#  'я же тебя просил меня разбудить',
#  'тому некому было помочь',
#  'том не был занят',
#  'как бы ты посоветовал мне поступить',
#  'я хотел бы поехать во францию',
#  'я встретил его случайно на улице',
#  'том сегодня мне это сказал',
#  'математик такого бы не сказал',
#  'они мои не настоящие родители',
#  'они хотят чтобы кто-нибудь им помог',
#  'том ничего мне не моворит',
#  'многие птицы на зиму улетают на юг',
#  'я же вас просил меня разбудить',
#  'мне было нечего скрывать',
#  'я хотел бы порисовать',
#  'мне будут нужны подробности',
#  'я бы хотел столик у окна',
#  'я хочу чтобы нас не поймали',
#  'я никогда больше не увижу тома',
#  'я никогда с этим не соглашусь',
#  'том сейчас не может подойти к телефону',
#  'я никогда не забуду его выражение лица',
#  'я не могу жить без тома',
#  'я их видел три недели назад',
#  'когда я его видел в последний раз',
#  'я написал вчера письмо',
#  'он больше не может идти',
#  'никто больше туда не ходит',
#  'я не хочу ничего пить',
#  'я бы хотел быть камнем',
#  'настоящий друг бы мне помог',
#  'том очень этим гордился',
#  'я не хочу с тобой больше играть',
#  'кто может мне это объяснить',
#  'я и сам уже не рад',
#  'он мне сделал комплимент',
#  'что ты еще сделал',
#  'я ему все рассказываю',
#  'кто тебе это все сказал',
#  'том - один из лучших моих друзей',
#  'том не хочет сегодня никого видеть',
#  'ты любишь яблоки или апельсины',
#  'у меня сейчас есть немного денег',
#  'я больше никогда не увижу тома',
#  'интерфейс очень интуитивно понятен',
#  'у меня кое-что есть для тома',
#  'чем ты завтра будешь заниматься в это время',
#  'кто-то это уже сделал',
#  'том действует мне на нервы',
#  'том уже должен быть дома',
#  'ты яблоки любишь или апельсины',
#  'тома здесь не будет до половины третьего',
#  'они были не готовы',
#  'я ему сам позвоню',
#  'том сегодня не хочет никого видеть',
#  'мне нечего больше переводить',
#  'хирухг забыл что-то внутри пациента',
#  'эта способность к общению очень нам помогает',
#  'я не живу в бостоне',
#  'мне пришлось делать все самому',
#  'камое это имеет отношение к школе',
#  'я еще этого не сделал',
#  'том ничего не знает о семье мэри',
#  'мы не можем ничего сделать',
#  'том никогда мне не называл свою фамилию',
#  'я этого еще не сделал',
#  'возьми его ключи от машины',
#  'мы не можем прожить ни дня без воды',
#  'я не могу поехать в этом году за границу',
#  'он очень этого хочет',
#  'я там буду в пять',
#  'почему никто нам не помогает',
#  'я просто хоку исчезнуть',
#  'я смогу там быть через час',
#  'говорят погода в горах быстро меняется',
#  'кто тебе это все сказал',
#  'возьми ключи от его машины',
#  'я ничего не могу доказать',
#  'что том на это скажет',
#  'я никого здесь не знаю',
#  'я тоже хотел бы услышать твой голос',
#  'я сейчас живу в бостоне',
#  'том никогда нам ничего не рассказывает',
#  'тому было не с кем играть',
#  'том еще ничего мне не сказал',
#  'я неплохо провел вчера время',
#  'том сейчас не живет в бостоне',
#  'том очень мне помог',
#  'здесь ничего никогда не происходит',
#  'я знаю что это для тебя важно',
#  'что том на это скажер',
#  'им нужны были деньги',
#  'он был не готов',
#  'я не могу ничего найти',
#  'фильм мне показался интересным',
#  'надеюсь вы все понимаете',
#  'он не сказал мне ни слова',
#  'я тебя правда не понимаю',
#  'я все им рассказываю',
#  'том уже выпил три чашки кофе',
#  'я их сегодня не видел',
#  'у меня было все под контролем',
#  'если у тебя будет время завтра приходи ко мне',
#  'том все мне рассказал',
#  'пусть это свиньи едят',
#  'я не могу в этом году поехать за границу',
#  'я ничего не хочу об этом знать',
#  'я их тоже не могу найти',
#  'том выпил уже три чашки кофе',
#  'она была тогда маленькой девочкой',
#  'тома не будет здесь до половины третьего',
#  'я бы хотел куриного супа',
#  'том и мэри объявили сегодня о своей помолвке',
#  'том все мне расскатал',
#  'твои комментарии всегда мне очень помогали',
#  'я его случайно встретил на улице',
#  'какая гора самая высокая в европе',
#  'вот как оно все обернулось',
#  'странно что нас никто не знает',
#  'мэри не была готова',
#  'мы были не готовы',
#  'он сделал мне комплимент',
#  'они не мои настоящие родители',
#  'я не пытался никого убить',
#  'они только что их нашли',
#  'я им сам позвоню',
#  'том каждое утро читает газету',
#  'мне больше нечего переводить',
#  'я беру все с собой',
#  'надо было позвонить и заранее забронировать столик',
#  'он что-то искал в темноте',
#  'я был не пристегнут',
#  'том сказал что ничего не хочет есть',
#  'настоящий друг мне бы помог',
#  'том никогда туда больше не вернется',
#  'я хотел бы куриного супа',
#  'том уже должен быть дола',
#  'тому нужен был молоток',
#  'я ничего в последнее время не покупал',
#  'мы много времени проводим вместе',
#  'я знаю что для тебя это важно',
#  'почему всн на нас смотрят',
#  'сколько шебе тогда было лет',
#  'что еще ты можешь рассказать нам о томе',
#  'по-моему я это сделал неправильно',
#  'она не была готова',
#  'я хотел бы выучить финский',
#  'она тратит все свои деньги на одежду',
#  'том продал сегодня три холодильника',
#  'кен был вчера дома',
#  'я только что его исправил',
#  'том - один из моих лучших друзей',
#  'что именно сказал тебе том',
#  'я хотел бы сам разбудить их',
#  'я так его любила',
#  'мост очень длинный и очень высокий',
#  'никто ничем никому не обязан',
#  'они пили белое сухое вино',
#  'он больше не может ждать',
#  'я знаю что том сейчас в бостоне',
#  'иди сюда я тебе еще кое-что покажу',
#  'эта способность к общению нам очень помогает',
#  'я никогда ничего от тебя не скрывал',
#  'больше мы для него ничего не можем сделать',
#  'у меня сегодня тоже контрольная',
#  'я никого не хотел ввести в заблуждение',
#  'кен вчера был дома',
#  'я бы хотел выучить латышский',
#  'том больше не хотел об этом думать',
#  'рому было нечего сказать',
#  'том еще нас не видел',
#  'мы должны всем им помочь',
#  'чего ты свой нос повсюду суешь',
#  'мы ни дня не можем прожить без воды']

# %% [markdown]
# ## Группировка предложений

# %%
groups = []
threshold = 0.85
used = [False for _ in range(len(data))]
for current_id in range(len(data)):
    if (used[current_id]):
        continue
    print(current_id)
    current_group = []
    current_group.append(data[current_id])
    used[current_id] = True
    for next_id in range(current_id + 1, len(data)):
        if (used[next_id]):
            continue
        line1 = data[current_id]
        line2 = data[next_id]
        if (cosine_count.is_rewrite_cosine_count(line1, line2, threshold) or
           dam_lev_dist.is_rewrite_damerau_levenshtein_distance(line1, line2, threshold) or
           distance_L2.is_rewrite_distance_L2(line1, line2, threshold) or
           ngrams.is_rewrite_tverskiy_ngram(line1, line2, threshold)):
            if (pronouns.check_pronoun_correspondence(line1, line2) or hamming_distance_custom.is_rewrite_hamming_distance_custom(line1, line2, threshold)):
                current_group.append(line2)
                used[next_id] = True
    groups.append(current_group)
# Out:
# 0
# 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 20
#      15 line2 = data[next_id]
#      16 if (cosine_count.is_rewrite_cosine_count(line1, line2, threshold) or
#      17    dam_lev_dist.is_rewrite_damerau_levenshtein_distance(line1, line2, threshold) or
#      18    distance_L2.is_rewrite_distance_L2(line1, line2, threshold) or
#      19    ngrams.is_rewrite_tverskiy_ngram(line1, line2, threshold)):
# ---> 20     if (pronouns.check_pronoun_correspondence(line1, line2) or hamming_distance_custom.is_rewrite_hamming_distance_custom(line1, line2, threshold)):
#      21         current_group.append(line2)
#      22         used[next_id] = True
#
# NameError: name 'hamming_distance_custom' is not defined

# %%
groups
# Out:
# [['ты нашел их или нет'],
#  ['почему она так со мной поступает'],
#  ['никто туда больше не ходит', 'никто больше туда не ходит'],
#  ['у него с собой не было тогда денег', 'у него тогда не было с собой денег'],
#  ['почему они с нами так поступают'],
#  ['он всю ночь стонал от сильной боли'],
#  ['я больше не хочу с тобой играть', 'я не хочу с тобой больше играть'],
#  ['тому было тогда всего тринадцать лет'],
#  ['что сделал том с деньгами', 'что сделел том с деньгами'],
#  ['том меня сейчас хочет видеть', 'том хочет меня сейчас видеть'],
#  ['он даже меня не замечает'],
#  ['тебе это все нравится'],
#  ['я его больше не увижу', 'я больше его не увижу'],
#  ['почему она так с ней поступает',
#   'почему они так с ним поступают',
#   'почему она так с ним поступает'],
#  ['я хотел бы учиться в бостоне'],
#  ['том и мэри объявили сегодня о своей пбмолвке',
#   'том и мэри объявили сегодня о своей помолвке'],
#  ['том этим сейчас занимается'],
#  ['я не могу больше ждать', 'я больше не могу ждать'],
#  ['мост очень длинный и высокий', 'мост очень длинный и очень высокий'],
#  ['том был просто не готов'],
#  ['пусть свиньи это едят', 'пусть это свиньи едят'],
#  ['я ничего не хочу делать', 'я ничего не хочу читать'],
#  ['ты хотел мне рассказать о свободе', 'ты хотел рассказать мне о свободе'],
#  ['что пел джон на сцене', 'что джон пел на сцене'],
#  ['я написал влера письмо', 'я написал вчера письмо'],
#  ['тому это тоже не нравится'],
#  ['сколько сейчас времени в париже'],
#  ['мы не были готовы', 'мы были не готовы'],
#  ['они их только что нашли', 'они только что их нашли'],
#  ['тому было больше не к кому обратиться'],
#  ['том не знает ничего о семье мэри', 'том ничего не знает о семье мэри'],
#  ['я живу сейчас в бостоне', 'я сейчас живу в бостоне'],
#  ['я ничего не хочу пить', 'я не хочу ничего пить'],
#  ['мне нужны будут подробности', 'мне будут нужны подробности'],
#  ['мы ничего не можем сделать',
#   'мы не можем ничего сделать',
#   'больше мы для него ничего не можем сделать'],
#  ['он сказал что вчера был дома'],
#  ['твои комментарии мне всегда очень помогали',
#   'твои комментарии всегда мне очень помогали'],
#  ['они никогда меня не слушают'],
#  ['они три года провели в тюрьме', 'они провели три года в тюрьме'],
#  ['вчера был просто не мой день', 'вчера просто был не мой день'],
#  ['я поймал сегодня три рыбы'],
#  ['я хочу что-нибудь сделать для тома'],
#  ['тому было нечего сказать', 'рому было нечего сказать'],
#  ['я сделал все правильно'],
#  ['я напишу или позвоню тебе на следующей неделе',
#   'я тебе напишу или позвоню на следующей неделе'],
#  ['я тоже завтра пойду в университет'],
#  ['чем ты будешь заниматься завтра в это время',
#   'чем ты завтра будешь заниматься в это время'],
#  ['я хотел бы быть камнем', 'я бы хотел быть камнем'],
#  ['я рмогу там быть через час', 'я смогу там быть через час'],
#  ['мне никогда не нужно было столько денег'],
#  ['том бы никогда не согласился', 'том бы никогда не соглхсился'],
#  ['извините я хотел бы ьто примерить', 'извините я хотел бы это примерить'],
#  ['кто мне может это объяснить', 'кто может мне это объяснить'],
#  ['ты не будешь один', 'ты не будеоь один'],
#  ['том сегодня не может прийти', 'том не может сегодня прийти'],
#  ['я тебя видел с высоким парнем', 'я видел тебя с высоким парнем'],
#  ['я не езжу в школу на автобусе', 'я езжу в школу не на автобусе'],
#  ['она все свои деньги тратит на одежду',
#   'она тратит все свои деньги на одежду'],
#  ['том не может жить без мэри'],
#  ['том всегда меня смешит', 'том меня всегда смешит'],
#  ['том мне сегодня это сказал', 'том сегодня мне это сказал'],
#  ['я хочу сделать что-то со своей жизнью',
#   'я хочу сделать что-то со своей жизною'],
#  ['почему все на нас смотрят', 'почему всн на нас смотрят'],
#  ['том здесь больше не работает', 'том больше здесь не работает'],
#  ['я редко видел его в школе', 'я его редко видел в школе'],
#  ['я думаю вса время о томе', 'я думаю все время о томе'],
#  ['мы много времени провгдим вместе', 'мы много времени проводим вместе'],
#  ['что могло с ними случиться'],
#  ['мы будем делать все по-своему'],
#  ['я сейчас не могу говорить', 'я не могу сейчас говорить'],
#  ['где был том весь день'],
#  ['я здесь часто ем'],
#  ['мы их только что нашли', 'мы только что их нашли'],
#  ['я все ей рассказываю', 'я все им рассказываю'],
#  ['том больше мне не доверяет'],
#  ['никто не знает чуо на самом деле происходит',
#   'никто не знает что на самом деле происходит'],
#  ['какая гора самая высокая в мире', 'какая гора самая высокая в европе'],
#  ['том не может сейчас подойти к телефону',
#   'том сейчас не может подойти к телефону'],
#  ['том не хочет никого видеть',
#   'том не хочет сегодня никого видеть',
#   'том сегодня не хочет никого видеть'],
#  ['многие птицы осенью улетают на юг', 'многие птицы на зиму улетают на юг'],
#  ['какое это имеет отношение к школе', 'камое это имеет отношение к школе'],
#  ['я не хотел ввести никого в заблуждение',
#   'я никого не хотел ввести в заблуждение'],
#  ['том нам ничего не дал',
#   'том ничего нам не платит',
#   'том ничего нам не дал'],
#  ['я покажу вам несколько фотографий', 'я вам покажу несколько фотографий'],
#  ['здесь есть поблизости банкомат', 'здесь поблизости есть банкомат'],
#  ['у меня нет дома компьютера', 'у меня дома нет компьютера'],
#  ['мы теряем здесь время'],
#  ['можешь меня высадить у библиотеки'],
#  ['том был мне как отец'],
#  ['я сделал это все для тебя'],
#  ['мне было не с кем поговорить'],
#  ['я хотел бы столик у окна', 'я бы хотел столик у окна'],
#  ['тем ничего нам не платит'],
#  ['с этим нужно что-то немедленно делать'],
#  ['том уже это сделал'],
#  ['том никогда мне не казывал свою фамилию',
#   'том никогда мне не называл свою фамилию'],
#  ['том никогда тебя больше не увидит', 'том никогда больше тебя не увидит'],
#  ['я бы тоже хотел услышать твой голос',
#   'я тоже хотел бы услышать твой голос'],
#  ['я больше не могу доверять тому'],
#  ['том сегодня будет здесь'],
#  ['я бы хотел порисовать', 'я хотел бы порисовать'],
#  ['лакая гора самая высокая в европе'],
#  ['мы их никогда не найдем'],
#  ['том тогда был здесь', 'том был тогда здесь'],
#  ['ты играешь в футбол или регби', 'ты в футбол играешь или в регби'],
#  ['я говорю также на испанском'],
#  ['зачем тому была нужна отвертка'],
#  ['я бы хотел поехать во францию', 'я хотел бы поехать во францию'],
#  ['я ничего не могу найти', 'я не могу ничего найти'],
#  ['мне нечего было скрывать', 'мне было нечего скрывать'],
#  ['я здесь никого не знаю', 'я никого здесь не знаю'],
#  ['я тебя не спрашиваю том'],
#  ['этой мечте было не суждено осуществиться'],
#  ['я привык что том все время на меня орет'],
#  ['том тебе звонил вчера вечером'],
#  ['я сегодня не был занят', 'я не был сегодня занят'],
#  ['я тебе уже все сказал'],
#  ['странно что никто нас не знает', 'странно что нас никто не знает'],
#  ['он не был готов', 'он был не готов'],
#  ['я не живу в финляндии', 'я живу не в финляндии'],
#  ['я ему заплатил на прошлой неделе', 'я заплатил ему на прошлой неделе'],
#  ['я правда тебя не понимаю', 'я тебя правда не понимаю'],
#  ['говорят в горах погода быстро меняется',
#   'говорят погода в горах быстро меняется'],
#  ['мне придется это ещм раз обдумать', 'мне придется это еще раз обдумать'],
#  ['почему он так со мной поступает'],
#  ['сколько тебе тогда было лет', 'сколько шебе тогда было лет'],
#  ['прибавить пять к десяти легко'],
#  ['он не сказал мно ни слова', 'он не сказал мне ни слова'],
#  ['думаю я мог бы и один это сделать'],
#  ['я бы хотел выучить финский', 'я хотел бы выучить финский'],
#  ['у тебя есть дома компьютер', 'у тебя дома есть компьютер'],
#  ['хирург забыл что-то внутри пациента',
#   'хирухг забыл что-то внутри пациента'],
#  ['он не может больше идти',
#   'он больше не может идти',
#   'он больше не может ждать'],
#  ['том сможет это сделать без нашей помощи'],
#  ['он никогда мне не помогает'],
#  ['том яблоко ест или банан', 'том ест яблоко или банан'],
#  ['мы сегодня поговорим с томом'],
#  ['том мне действует на нервы', 'том действует мне на нервы'],
#  ['том обещал никогда этого больше не делать'],
#  ['я просто был невнимателен'],
#  ['том был не единственным свидетелем'],
#  ['том очень мае помог', 'том очень мне помог'],
#  ['ты едешь на поезде или на машине', 'ты на поезде едешь или на машине'],
#  ['не слышно было ни звука'],
#  ['почему она с ним так поступает'],
#  ['я там встретил тома'],
#  ['мне сегодня не нужно никуда идти'],
#  ['том не живет в бостоне', 'том сейчас не живет в бостоне'],
#  ['я вчера неплохо провел время', 'я неплохо провел вчера время'],
#  ['у меня есть кое-что для тома', 'у меня кое-что есть для тома'],
#  ['я бы хотел выучить латышсккй', 'я бы хотел выучить латышский'],
#  ['я не хочу больше на вас работать'],
#  ['мэри была не готова', 'мэри не была готова'],
#  ['все говорят что они невиновны', 'все они говорят что невиновны'],
#  ['том больше не может здесь оставаться'],
#  ['том продал сегоднь три холодильника',
#   'том продал сегодня три холодильника'],
#  ['у тебя в детстве была любимая книга'],
#  ['я знаю что все вы трусы'],
#  ['он был тогда в америке', 'он тогда был в америке'],
#  ['мэри говорит что ничего не будет делать'],
#  ['я жить не могу без тома', 'я не могу жить без тома'],
#  ['тому был нужен молоток', 'тому нужен был молоток'],
#  ['я никогда ни о чем тебя не просил'],
#  ['она сказала что вчера была дома'],
#  ['я только что это сделал'],
#  ['я полностью с ними согласен'],
#  ['мы не были так заняты'],
#  ['мне пришлось все делать самому', 'мне пришлось делать все самому'],
#  ['том не хотел никуда идти'],
#  ['я не хочу ничего читать'],
#  ['я никогда не забуду выражение его лица',
#   'я никогда не забуду его выражение лица'],
#  ['что еще я получу'],
#  ['у меня тоже сегодня контрольная', 'у меня сегодня тоже контрольная'],
#  ['я буду там в пять', 'я там буду в пять'],
#  ['мы больше не хотим ждать'],
#  ['я никогда от тебя ничего не скрывал',
#   'я никогда ничего от тебя не скрывал'],
#  ['она никогда нам ничего не рассказывает',
#   'том никогда нам ничего не рассказывает'],
#  ['я кричу но никто меня не слышит'],
#  ['они не были готовы', 'они были не готовы'],
#  ['я ничего им не дал'],
#  ['не думаю что можно что-то сделать'],
#  ['я думаю что здесь мы в безопасности'],
#  ['я был вынужден уйти'],
#  ['она была не готова', 'она не была готова'],
#  ['фильм показался мне интересным', 'фильм мне показался интересным'],
#  ['хорошо что тома здесь нет'],
#  ['почему ты просто не можешь позвонить им'],
#  ['им были нужны деньги', 'им нужны были деньги'],
#  ['том ничего мне не говорит', 'том ничего мне не моворит'],
#  ['я бы хотел поцеловать мэри'],
#  ['я просто хочу исчезнуть', 'я просто хоку исчезнуть'],
#  ['я только что его доделал'],
#  ['я завтра им позвоню'],
#  ['на печи старая кошка возится со своими котятами'],
#  ['я же тебя просил меня разбудить'],
#  ['тому некому было помочь'],
#  ['том не был занят'],
#  ['как бы ты посоветовал мне поступить'],
#  ['я встретил его случайно на улице', 'я его случайно встретил на улице'],
#  ['математик такого бы не сказал'],
#  ['они мои не настоящие родители', 'они не мои настоящие родители'],
#  ['они хотят чтобы кто-нибудь им помог'],
#  ['я же вас просил меня разбудить'],
#  ['я хочу чтобы нас не поймали'],
#  ['я никогда больше не увижу тома', 'я больше никогда не увижу тома'],
#  ['я никогда с этим не соглашусь'],
#  ['я их видел три недели назад'],
#  ['когда я его видел в последний раз'],
#  ['настоящий друг бы мне помог', 'настоящий друг мне бы помог'],
#  ['том очень этим гордился'],
#  ['я и сам уже не рад'],
#  ['он мне сделал комплимент', 'он сделал мне комплимент'],
#  ['что ты еще сделал'],
#  ['я ему все рассказываю'],
#  ['кто тебе это все сказал', 'кто тебе это все сказал'],
#  ['том - один из лучших моих друзей', 'том - один из моих лучших друзей'],
#  ['ты любишь яблоки или апельсины', 'ты яблоки любишь или апельсины'],
#  ['у меня сейчас есть немного денег'],
#  ['интерфейс очень интуитивно понятен'],
#  ['кто-то это уже сделал'],
#  ['том уже должен быть дома', 'том уже должен быть дола'],
#  ['тома здесь не будет до половины третьего',
#   'тома не будет здесь до половины третьего'],
#  ['я ему сам позвоню'],
#  ['мне нечего больше переводить', 'мне больше нечего переводить'],
#  ['эта способность к общению очень нам помогает',
#   'эта способность к общению нам очень помогает'],
#  ['я не живу в бостоне'],
#  ['я еще этого не сделал', 'я этого еще не сделал'],
#  ['возьми его ключи от машины', 'возьми ключи от его машины'],
#  ['мы не можем прожить ни дня без воды',
#   'мы ни дня не можем прожить без воды'],
#  ['я не могу поехать в этом году за границу',
#   'я не могу в этом году поехать за границу'],
#  ['он очень этого хочет'],
#  ['почему никто нам не помогает'],
#  ['я ничего не могу доказать'],
#  ['что том на это скажет', 'что том на это скажер'],
#  ['тому было не с кем играть'],
#  ['том еще ничего мне не сказал'],
#  ['здесь ничего никогда не происходит'],
#  ['я знаю что это для тебя важно', 'я знаю что для тебя это важно'],
#  ['надеюсь вы все понимаете'],
#  ['том уже выпил три чашки кофе', 'том выпил уже три чашки кофе'],
#  ['я их сегодня не видел'],
#  ['у меня было все под контролем'],
#  ['если у тебя будет время завтра приходи ко мне'],
#  ['том все мне рассказал', 'том все мне расскатал'],
#  ['я ничего не хочу об этом знать'],
#  ['я их тоже не могу найти'],
#  ['она была тогда маленькой девочкой'],
#  ['я бы хотел куриного супа', 'я хотел бы куриного супа'],
#  ['вот как оно все обернулось'],
#  ['я не пытался никого убить'],
#  ['я им сам позвоню'],
#  ['том каждое утро читает газету'],
#  ['я беру все с собой'],
#  ['надо было позвонить и заранее забронировать столик'],
#  ['он что-то искал в темноте'],
#  ['я был не пристегнут'],
#  ['том сказал что ничего не хочет есть'],
#  ['том никогда туда больше не вернется'],
#  ['я ничего в последнее время не покупал'],
#  ['что еще ты можешь рассказать нам о томе'],
#  ['по-моему я это сделал неправильно'],
#  ['кен был вчера дома', 'кен вчера был дома'],
#  ['я только что его исправил'],
#  ['что именно сказал тебе том'],
#  ['я хотел бы сам разбудить их'],
#  ['я так его любила'],
#  ['никто ничем никому не обязан'],
#  ['они пили белое сухое вино'],
#  ['я знаю что том сейчас в бостоне'],
#  ['иди сюда я тебе еще кое-что покажу'],
#  ['том больше не хотел об этом думать'],
#  ['том еще нас не видел'],
#  ['мы должны всем им помочь'],
#  ['чего ты свой нос повсюду суешь']]

# %%
len(groups)
# Out:
# 274

# %%
for g in groups:
    for l in g:
        if ('нос' in l):
            print(g)
            break
# Out:
# ['мне нужны будут подробности', 'мне будут нужны подробности']
# ['я полностью с ними согласен']
# ['я думаю что здесь мы в безопасности']
# ['эта способность к общению очень нам помогает', 'эта способность к общению нам очень помогает']
# ['чего ты свой нос повсюду суешь']

# %%
for l in data:
    if ('темноте' in l):
        print(l)
# Out:
# он что-то искал в темноте
